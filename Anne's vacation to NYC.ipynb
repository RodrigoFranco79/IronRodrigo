# %% [markdown]
# # Anne's vacation

# %%
from IPython.display import Image
Image ("https://profile-images.xing.com/images/c1f54219f5ec4980855b0b060efa2cd3-1/anne-mieth.256x256.jpg")

# %% [markdown]
# ### A very deserved vacation for a perfect wife an momm

# %%
from IPython.display import Image
Image ("https://media.tacdn.com/media/attractions-splice-spp-674x446/06/fe/76/22.jpg")

# %% [markdown]
# [this is alink](https://www.youtube.com/watch?v=cD7fVDMHWFk)

# %%
from IPython.display import YouTubeVideo
# aVideo Tour of Williamsburg, Brooklyn, New York.
# Video credit: New York Habitat.
YouTubeVideo('cD7fVDMHWFk')

# %% [markdown]
# - TOP 1: Go to the places where we justed to leave
# - TOP 2: Bike the same routs like before
# - TOP 3: Visits friends from back on the day
