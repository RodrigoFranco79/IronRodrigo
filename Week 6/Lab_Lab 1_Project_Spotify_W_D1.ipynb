# %% [markdown]
# # Create a function to scrape the Billboards 100 HOT songs and create a local dataframe of songs with them including:

# %%
## 1. installing required libraries.

from bs4 import BeautifulSoup
import requests
import pandas as pd

import sys
# !conda install --yes --prefix {sys.prefix} -c anaconda beautifulsoup4
# !conda install --yes --prefix {sys.prefix} -c anaconda requests
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done

# %%
# 2. download the webpage 
url = "https://www.billboard.com/charts/hot-100/"

# %% [markdown]
# <b> using request package

# %%
# 3. download html with a get request 
page = requests.get(url)
page.status_code
# Out:
# 200

# %%
def hot_songs():
    response = requests.get(url)
    soup = bs(response.content, "html.parser")
    song_list = soup.select('.o-chart-results-list__item h3')
    songs = []

# %% [markdown]
# ## Song’s name

# %%
song_list=soup.select(".o-chart-results-list__item h3")
song_list[0].get_text().strip()
# Out:
# 'As It Was'

# %%
soup.select(".o-chart-results-list__item h3")
# Out:
# [<h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet" id="title-of-a-story">
#
#
#
#
#  					As It Was
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					Bad Habit
#
#  </h3>,
#  <h3 class="c-title a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only" id="title-of-a-story">
#
#
#
#
#  					About Damn Time
#
#  </h3>,
# ...

# %%
songs = []

# %%
for i in song_list:
    s = i.get_text()
    songs.append(s.strip())
song_list = soup.select('span.a-no-trucate')
song = []

# %% [markdown]
# ## Song’s artist

# %%
artist_list=soup.select(".o-chart-results-list__item span")
artist_list[0].get_text().strip()
# Out:
# '1'

# %%
soup.select(".o-chart-results-list__item span")
# Out:
# [<span class="c-label a-font-primary-bold-l u-font-size-32@tablet u-letter-spacing-0080@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Harry Styles
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	1
#  </span>,
#  <span class="c-label a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet">
#
#  	22
#  </span>,
# ...

# %%
soup.select(".c-label.a-no-trucate")
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Harry Styles
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Steve Lacy
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	Lizzo
#  </span>,
# ...

# %% [markdown]
# #### Building the dataframe

# %%
#initialize empty lists
songs= []
artists= []

# %%
# define the number of iterations of our for loop 
# by checking how many elements are in the retrieved result set
# (this is equivalent but more robust than just explicitly defining 100 iterations)
num_iter = len(soup.select(".c-label.a-no-trucate"))
num_iter
# Out:
# 100

# %%
soup.select("#title-of-a-story")
# Out:
# [<h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Songwriter(s):
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Producer(s):
#
#  </h3>,
#  <h3 class="c-title a-font-primary-medium-s u-letter-spacing-0021" id="title-of-a-story">
#
#
#
#
#  					Imprint/Promotion Label:
#
#  </h3>,
#  <h3 class="c-title a-font-primary-m lrv-u-color-brand-primary:hover" id="title-of-a-story">
#  <a class="c-title__link lrv-a-unstyle-link" href="https://www.billboard.com/culture/tv-film/harry-styles-policeman-premiere-toronto-tiff-1235137345/">
#
#
#  					Harry Styles Greets Fans, Joins Cast &amp; Director for 'My Policeman' Premiere In Toronto
#  					</a>
#  </h3>,
#  <h3 class="c-title a-font-primary-bold-s u-letter-spacing-0026 lrv-u-color-black" id="title-of-a-story">
#
#
#
#
#  					Gains in Weekly Performance
#
#  </h3>,
# ...

# %%
# iterate through the result set and retrive all the data
for i in range(num_iter):
    songs.append(soup.select(".o-chart-results-list__item #title-of-a-story")[i].get_text(strip=True)) ## getting movies song's names
    artists.append(soup.select(".c-label.a-no-trucate")[i].get_text(strip=True)) ## getting dir and artists names

# %%
print(artists)
# Out:
# ['Harry Styles', 'Steve Lacy', 'Lizzo', 'Kate Bush', 'Nicky Youre & dazy', 'Elton John & Britney Spears', 'Nicki Minaj', 'Post Malone Featuring Doja Cat', 'Beyonce', 'Future Featuring Drake & Tems', 'Bad Bunny & Chencho Corleone', 'Harry Styles', 'Morgan Wallen', 'OneRepublic', 'Luke Combs', 'Bad Bunny', 'DJ Khaled Featuring Rick Ross, Lil Wayne, JAY-Z, John Legend & Fridayy', 'Jack Harlow', 'Glass Animals', 'Morgan Wallen', 'DJ Khaled Featuring Drake & Lil Baby', 'Cole Swindell', 'Drake Featuring 21 Savage', 'The Kid LAROI & Justin Bieber', 'Doja Cat', 'Joji', 'Jon Pardi', 'Tyler Hubbard', 'DJ Khaled Featuring Future & SZA', 'Bad Bunny', 'DJ Khaled Featuring Future & Lil Baby', 'Latto', 'Yung Gravy', 'Justin Bieber', 'Ed Sheeran', 'Lil Tjay', 'Karol G x Maldy', 'Bailey Zimmerman', 'Bad Bunny', 'Lil Baby', 'Elton John & Dua Lipa', 'Zach Bryan', 'Jelly Roll', 'Marshmello & Khalid', 'Bailey Zimmerman', 'Karol G', 'Charlie Puth Featuring Jung Kook', 'Em Beihold', 'DJ Khaled Featuring Ka
# ...

# %%
songs
# Out:
# ['As It Was',
#  'Bad Habit',
#  'About Damn Time',
#  'Running Up That Hill (A Deal With God)',
#  'Sunroof',
#  'Hold Me Closer',
#  'Super Freaky Girl',
#  'I Like You (A Happier Song)',
#  'Break My Soul',
#  'Wait For U',
#  'Me Porto Bonito',
#  'Late Night Talking',
#  'You Proof',
#  "I Ain't Worried",
#  'The Kind Of Love We Make',
#  'Titi Me Pregunto',
#  'God Did',
#  'First Class',
#  'Heat Waves',
#  'Wasted On You',
#  'Staying Alive',
#  'She Had Me At Heads Carolina',
#  'Jimmy Cooks',
#  'Stay',
#  'Vegas',
#  'Glimpse Of Us',
#  'Last Night Lonely',
#  '5 Foot 9',
#  'Beautiful',
#  'Moscow Mule',
#  'Big Time',
#  'Big Energy',
#  'Betty (Get Money)',
#  'Ghost',
#  'Shivers',
#  'Beat The Odds',
#  'Gatubela',
#  'Rock And A Hard Place',
#  'Efecto',
#  'In A Minute',
#  'Cold Heart (PNAU Remix)',
#  'Something In The Orange',
#  'Son Of A Sinner',
#  'Numb',
#  'Fall In Love',
#  'Provenza',
#  'Left And Right',
#  'Numb Little Bug',
# ...

# %%
# each list becomes a column
bilboard = pd.DataFrame({"songs":songs,
                       "artists":artists})

bilboard.head(100)
# Out:
#                                      songs                        artists
# 0                                As It Was                   Harry Styles
# 1                                Bad Habit                     Steve Lacy
# 2                          About Damn Time                          Lizzo
# 3   Running Up That Hill (A Deal With God)                      Kate Bush
# 4                                  Sunroof             Nicky Youre & dazy
# ..                                     ...                            ...
# 95                 Thought You Should Know                  Morgan Wallen
# 96                 2 Be Loved (Am I Ready)                          Lizzo
# 97                       Wait In The Truck  HARDY Featuring Lainey Wilson
# 98                            La Corriente          Bad Bunny & Tony Dize
# 99            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
#
# [100 rows x 2 columns]
